# %%
load("../rdata/.RData")

# %%
attach(price4)

# %%
par(mfcol=c(2,2))

# %%
plot(x5202, type="l", main= "板硝子")
# Out:
# Plot with title “板硝子”

# %%
plot(x4927, type="l", main= "ポーラHD")
# Out:
# Plot with title “ポーラHD”

# %%
plot(x7272, type="l", main= "ヤマハ")
# Out:
# Plot with title “ヤマハ”

# %%
plot(x4502, type="l", main= "武田薬品")
# Out:
# Plot with title “武田薬品”

# %%
detach(2)
